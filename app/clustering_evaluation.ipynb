# %% [markdown]
# # Clustering evaluation

# %%
from collections import Counter
import json
import numpy as np
import pandas as pd

from utils import generate_wordcloud
from wordcloud import WordCloud

# %%
RESULTS_PATH_KMEANS = "../results/kmeans_results_amann.json"
RESULTS_PATH_DBSCAN = "../results/dbscan_results_amann.json"
RESULTS_PATH_KMEANS_RD = "../results/kmeans_results_amann_rd.json"
RESULTS_PATH_DBSCAN_RD = "../results/dbscan_results_amann_rd.json"
MAX_ARI = 0.5
MIN_ARI = -0.1

# %%
with open(RESULTS_PATH_KMEANS) as f:
    kmeans = json.load(f)

kmeans_scores = {}
kmeans_top_words = {}

for k,v in kmeans.items():
    kmeans_scores[k] = v["scores"]
    kmeans_top_words[k] = v["tw"]
    
with open(RESULTS_PATH_KMEANS_RD) as f:
    kmeans_rd = json.load(f)

kmeans_rd_scores = {}
kmeans_rd_top_words = {}

for k,v in kmeans_rd.items():
    kmeans_rd_scores[k] = v["scores"]
    kmeans_rd_top_words[k] = v["tw"]

# %%
with open(RESULTS_PATH_DBSCAN) as f:
    dbscan = json.load(f)
    
dbscan_scores = {}

for k,v in dbscan.items():
    dbscan_scores[k] = v["scores"]
    

with open(RESULTS_PATH_DBSCAN_RD) as f:
    dbscan_rd = json.load(f)
    
dbscan_scores_rd = {}

for k,v in dbscan_rd.items():
    dbscan_scores_rd[k] = v["scores"]

# %%
kmeans_score_df = pd.DataFrame.from_dict(kmeans_scores, orient="index").sort_values("ari", ascending=False)
#kmeans_shortened_score_df = kmeans_score_df[(kmeans_score_df.ari >= MAX_ARI) | (kmeans_score_df.ari <= MIN_ARI)]

# %%
kmeans_score_rd_df = pd.DataFrame.from_dict(kmeans_rd_scores, orient="index").sort_values("ari", ascending=False)

# %%
dbscan_score_df = pd.DataFrame.from_dict(dbscan_scores, orient="index").sort_values("ari", ascending=False)

# %%
dbscan_score_rd_df = pd.DataFrame.from_dict(dbscan_scores_rd, orient="index").sort_values("ari", ascending=False)

# %%
kmeans_score_df.head(10)
# Out:
#                                ari        vm
# Barock/Klassik            0.723914  0.681082
# Barock/Realismus          0.651314  0.629702
# Aufklärung/Naturalismus   0.575708  0.480125
# Barock/Aufklärung         0.541778  0.461887
# Klassik/Naturalismus      0.478888  0.485033
# Barock/Naturalismus       0.392194  0.448967
# Barock/Biedermeier        0.371962  0.445968
# Aufklärung/Realismus      0.362792  0.438041
# Aufklärung/Biedermeier    0.359062  0.427227
# Romantik/Expressionismus  0.189024  0.333602

# %%
dbscan_score_df
# Out:
#                                    ari        vm
# Barock/Realismus              0.507069  0.540588
# Barock/Biedermeier            0.458552  0.518668
# Barock/Klassik                0.455296  0.478904
# Barock/Naturalismus           0.438779  0.449462
# Barock/Aufklärung             0.383122  0.384044
# Barock/Expressionismus        0.342997  0.221304
# Barock/Romantik               0.332189  0.225078
# Biedermeier/Expressionismus   0.317460  0.222133
# Aufklärung/Expressionismus    0.281526  0.132384
# Aufklärung/Romantik           0.274822  0.129170
# Klassik/Expressionismus       0.226976  0.099441
# Romantik/Biedermeier          0.205503  0.169062
# Klassik/Romantik              0.148006  0.054514
# Realismus/Expressionismus     0.139877  0.049878
# Aufklärung/Naturalismus       0.105600  0.067682
# Klassik/Naturalismus          0.086249  0.028917
# Romantik/Naturalismus         0.072570  0.062962
# Romantik/Realismus            0.070357  0.025292
# Romantik/Expressionismus      0.065513  0.173972
# Aufklärung/Realismus          0.064199  0.105291
# Naturalismus/Expressionismus  0.062784  0.051937
# Aufklärung/Biedermeier        0.059320  0.019196
# Klassik/Biedermeier           0.055366  0.052218
# Klassik/Realismus             0.049160  0.038989
# Biedermeier/Naturalismus      0.042579  0.113293
# Biedermeier/Realismus         0.040056  0.069298
# Aufklärung/Klassik            0.026632  0.136956
# Realismus/Naturalismus        0.018935  0.026073

# %%
kmeans_score_rd_df.head(10)
# Out:
#                                   ari        vm
# Barock/Realismus             0.869669  0.819960
# Barock/Klassik               0.844644  0.790353
# Barock/Biedermeier           0.778390  0.732983
# Barock/Naturalismus          0.702405  0.605282
# Aufklärung/Realismus         0.696755  0.607769
# Aufklärung/Naturalismus      0.604182  0.570226
# Aufklärung/Biedermeier       0.595207  0.523358
# Biedermeier/Expressionismus  0.579083  0.493523
# Barock/Aufklärung            0.550487  0.439650
# Aufklärung/Expressionismus   0.518710  0.487270

# %%
dbscan_score_rd_df.head(10)
# Out:
#                                   ari        vm
# Barock/Realismus             0.768186  0.712606
# Barock/Klassik               0.726451  0.644716
# Aufklärung/Realismus         0.679213  0.585714
# Aufklärung/Biedermeier       0.670706  0.549540
# Aufklärung/Naturalismus      0.611927  0.542674
# Barock/Biedermeier           0.576138  0.556792
# Romantik/Expressionismus     0.562018  0.552007
# Biedermeier/Expressionismus  0.558159  0.503471
# Barock/Expressionismus       0.537155  0.643096
# Barock/Naturalismus          0.528383  0.533094

# %% [markdown]
# ## top words

# %%
tw = pd.DataFrame.from_dict(kmeans_rd_top_words, orient="index")
tw.columns = ["cluster1", "cluster2"]

# %%
tw.head(3)
# Out:
#                                                             cluster1  \
# Barock/Aufklärung  [auff, vnd, hertz, diß, wil, jhr, auß, gantz, ...
# Barock/Klassik     [ew, tränen, tal, mut, liebchen, hain, not, le...
# Barock/Romantik    [auff, vnd, auß, jhr, hertze, itzt, deß, läst,...
#
#                                                             cluster2
# Barock/Aufklärung  [mädchen, dieß, amor, flur, hain, umher, frei,...
# Barock/Klassik     [auff, vnd, diß, hertz, wil, wol, auß, hertzen...
# Barock/Romantik    [tränen, not, tun, dieß, schmerz, schwert, vol...

# %%
tw = tw.loc[["Barock/Realismus"]]

# %%
def strjoin(liste):
    return " ".join(liste)

# %%
tw["cluster1"] = tw.cluster1.apply(strjoin)
tw["cluster2"] = tw.cluster2.apply(strjoin)

# %%
tw.head(3)
# Out:
#                                                            cluster1  \
# Barock/Realismus  mädchen sehnsucht dunkel duft not leis ew rasc...
#
#                                                         cluster2
# Barock/Realismus  auff vnd sey diß wil hertz wol auß hertzen jhr

# %%
for i in tw.cluster1.values:
    print(i)
    
for i in tw.cluster2.values:
    print(i)
# Out:
# mädchen sehnsucht dunkel duft not leis ew rasch sanft drin
# auff vnd sey diß wil hertz wol auß hertzen jhr

# %%
#generate_wordcloud(dict(Counter(cluster1_words)))
